# %%
#understanding basic networking components
#Its making the servers trust you are a computer not a human
#Thats what hackers do they talk the language of computers but am not a hackerrrr hahaahaha l am a scrappppeeeer
#The language of computers is http
#Some people usually block us if we send via python hence we use names of browsers etc
#Nowadays websites store most of their stuff in APIs when l get the API hence l will not be using messy data
#Here when you try and scrape data you don't gerrit coz some websites often use Javascript to load data dynamically
#Here the HTML u receive is almost empyty
#Javascript is calling an API in the background
#real data comes from JSON
#in APIS i will mostly deal with data in the form of Json
#When we send a request to the servers we need to encode then when it is coming back we decode
#APIs are a pretty strong tool weuuuuuhhhhh looked on the Mpesa API and what it does and weuh preetty useful tool
#They are the backbone of modern digital ecosystems
#Very intresting topics have been discussed

# %%
#import requests
#fetch('https://jsonplaceholder.typicode.com/todos/1')
#then(response => response.json())
#then(json => console.log(json))

# %%
import socket
#AF_INET says that it should use the IPV4
#SOCK_STREAM says that we use TCP=it is reliable and our data will not get lost
#UDP connection is used in video games etc
mysock= socket.socket(socket.AF_INET, socket.SOCK_STREAM)
#use ipv4 and TCP thats what the code above says
mysock.connect( ('data.pr4e.org',80))
#this above is the actual connection
#we decided to use http when using https we would have used TLS

#GET we want everything displayed
#the others like post,delete and put are reserved not easy for us to use
cmd = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\r\n\r\n'.encode()
mysock.send(cmd)
while True:
    data=mysock.recv(512)  
    if len(data)<1:
        break
    print(data.decode())
mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Wed, 18 Mar 2026 08:17:08 GMT
# Server: Apache/2.4.52 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# Accept-Ranges: bytes
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
# Content-Length: 167
#
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %%
import socket
mysock=socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org',80))
#already established a connection here
#so what you want to do
cmd= 'GET http://data.pr4e.org/romeo-full.txt HTTP/1.0\r\n\r\n'.encode()
mysock.send(cmd)
#the request is sent over the internet
while True:
    data=mysock.recv(512)
    if len(data)<1:
        break
    print(data.decode())
mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Thu, 19 Mar 2026 22:30:56 GMT
# Server: Apache/2.4.52 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "22a0-54f6609245537"
# Accept-Ranges: bytes
# Content-Length: 8864
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# Romeo and Juliet
# Act 2, Scene 2
#
# SCENE II. Capulet's orchard.
#
# Enter ROMEO
#
# ROMEO
#
# He jests at scars that never felt a wound.
# JULIET appear
# s above at a window
#
# But, soft! what light through yonder window breaks?
# It is the east, and Juliet is the sun.
# Arise, fair sun, and kill the envious moon,
# Who is already sick and pale with grief,
# That thou her maid art far more fair than she:
# Be not her maid, since she is envious;
# Her vestal livery is but sick and green
# And none but fools do wear it; cast it off.
# It is my lady, O, it is my love!
# O, that she knew she were!
# ...

# %%
print(ord('H'))
print(ord('h'))
x=b'abc'
type(x)
# Out:
# 72
# 104
# bytes

# %%
#import socket
#mysock=socket.socket(socket.AF_INET, socket.SOCK_STREAM)
#mysock.connect(('data.pr4e.org',80))
#already established a connection here
#so what you want to do
#cmd= 'GET http://data.pr4e.org/romeo-full.txt HTTP/1.0\r\n\r\n'.encode()
#mysock.send(cmd)
#all this is so common why not put in a library that does all this for us
#hence urllib does all this for us freely our work is to open
import urllib.request, urllib.parse , urllib.error
#there are npo headers but if yoy want the headers we can get them. Don't fooret to decode
fhandle= urllib.request.urlopen('http://data.pr4e.org/romeo.txt')
counts={}
easy={}
for line in fhandle:
    words=line.decode().split()
    #print(words)
    #the moment you split u create a list thats whhy dict and lists are best friends
    for word in words:
        if word in counts:
            counts[word]+=1
        else:
            counts[word]=1
        #easier version
        #the get check if the key is there blablabla...hahahaaha
        #add one each time
        easy[word]=easy.get(word,0)+1
print(easy)
print(counts)
# Out:
# {'But': 1, 'soft': 1, 'what': 1, 'light': 1, 'through': 1, 'yonder': 1, 'window': 1, 'breaks': 1, 'It': 1, 'is': 3, 'the': 3, 'east': 1, 'and': 3, 'Juliet': 1, 'sun': 2, 'Arise': 1, 'fair': 1, 'kill': 1, 'envious': 1, 'moon': 1, 'Who': 1, 'already': 1, 'sick': 1, 'pale': 1, 'with': 1, 'grief': 1}
# {'But': 1, 'soft': 1, 'what': 1, 'light': 1, 'through': 1, 'yonder': 1, 'window': 1, 'breaks': 1, 'It': 1, 'is': 3, 'the': 3, 'east': 1, 'and': 3, 'Juliet': 1, 'sun': 2, 'Arise': 1, 'fair': 1, 'kill': 1, 'envious': 1, 'moon': 1, 'Who': 1, 'already': 1, 'sick': 1, 'pale': 1, 'with': 1, 'grief': 1}

# %%
from bs4 import BeautifulSoup
print('installed successfully')
# Out:
# installed successfully

# %%
# !pip install beautifulsoup4

# %%
import bs4
print(bs4.__file__)
# Out:
# C:\Users\HomePC\miniconda3\envs\brain\Lib\site-packages\bs4\__init__.py

# %%
from bs4 import BeautifulSoup
print('working now')
# Out:
# working now

# %%
import urllib.request
from bs4 import BeautifulSoup

url=input('enter url')
html=urllib.request.urlopen(url).read()
soup= Beautifulsoup(html, 'html.parser')

#retriving all anchor tags
tags=soup('a')
for tag in tags:
    print(tag.get('href', None))

# %%
#only intrested with the data right hence why we remove the need of the passport
#bt its risky because of the man in the middle attacks
import urllib
from bs4 import BeautifulSoup
import ssl

#ignore ssl certificate errors
#this is what l was referring to as a 'passport' we ignore if the server has no passport
#at first what we are doing this context() is a new bodyguard and its very strict.
ctx = ssl.create_default_context()
#we now change some of the rules
#here you don't care on the host name
ctx.check_hostname=False
#here u also don't verify with third parties
ctx.verify_mode = ssl.CERT_NONE

url=input('enter url')
#we are ensuring that the server assumes that its is communicating to a chrome browser hahahahaha
headers= {'User-agent': 'Mozilla/5.0(Windows NT 10.0; Win64; x64)'}
req=urllib.request.Request(url, headers=headers)
html=urllib.request.urlopen(req,context=ctx).read()
soup=BeautifulSoup(html, 'html.parser')

#retriving all anchor tags
tags=soup('a')
for tag in tags:
    print(tag.get('href', None))
# Out:
# enter url http://pr4e.com
# https://twitter.com/drchuck
# index.php
# about.php
# https://podcast.dr-chuck.com/
# https://youtube.dr-chuck.com/
# https://www.dr-chuck.com/office
# https://www.dr-chuck.com/
# https://www.youtube.com/watch?v=z3o6yEzcnLc
# https://davidbombal.com/
# https://www.youtube.com/live/CifCr36qMws?si=OkDxJZnxUfMbY85J&t=308
# https://www.youtube.com/watch?v=gwwtae_flKk
# https://davidbombal.com/
# https://ihts.pr4e.com/
# https://www.py4e.com/
# https://www.dj4e.com/
# https://www.wa4e.com/
# https://www.pg4e.com
# https://www.cc4e.com
# https://www.ca4e.com
# https://online.umich.edu
# https://www.thelcmc.org/programs/computer-science
# https://rize.education/
